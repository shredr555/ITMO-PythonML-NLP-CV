# %% [markdown]
# # Задание 1
#
#
# 1.   С помощью библиотеки OpenCV считайте изображение
# 2.   Определите разрешение изображения.
# 3.   Определите интенсивность каналов R,G,B для пикселя, находящегося на пересечении 1937 строки и 2893 столбца матричного представления изображения.

# %%
# !pip install opencv-python==4.4.0.42
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 MB 7.1 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import cv2
print('OpenCV version:', cv2.__version__)
# Out:
# OpenCV version: 4.7.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# task 1_1
img_1 = '1.jpg'
img_1 = cv2.imread(img_1)

# task 1_2
h, w, c = img_1.shape
print('Width:  ', w)
print('Height: ', h)
print('Channels:', c)

# task 1_3
RGB_img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img_1)
plt.show()

R, G, B = RGB_img_1[1937][2893]
print('Red channel:', R)
print('Green channel: ', G)
print('Blue channel:  ', B)
print(R, ',', G, ',', B)
# Out:
# Width:   5758
# Height:  3839
# Channels: 3
# Red channel: 97
# Green channel:  99
# Blue channel:   2
# 97 , 99 , 2

# %% [markdown]
# # Задание 2
#
#
# 1.   С помощью библиотеки OpenCV считайте изображение
# 2.   Преобразуйте в палитру RGB
# 3. Выделите подматрицу пикселей, находящихся на пересечении строк в диапазоне от 2196 до 2895 включительно, и столбцов в диапазоне от 3340 до 3929 включительно, матричного представления изображения.

# %%
# task 2_1
img_2 = '2.jpg'
img_2 = cv2.imread(img_2)

# task 2_2
RGB_img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img_2)
plt.show()

# task 2_3
crop_img_2 = RGB_img_2[2196:2895, 3340:3929]
plt.imshow(crop_img_2)
plt.show()

# %% [markdown]
# # Задание 3
#
#
# 1. С помощью библиотеки OpenCV считайте изображение
# 2. Сожмите изображение до ширины 890, соблюдая пропорции исходного изображения. Важно: коэффициент отношения сторон при вычислениях не округляйте. Если высота не окажется целой, округлите значение до целого в меньшую сторону.
# 3. Сохраните сжатое изображение в палитре RGB.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#1.
bgr_img = cv2.imread('3.jpg')
img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)


#2.
h, w, c = img.shape
new_width = 890

k = float(w) / h
print(k)
dim = (new_width, int(new_width / k))

resized_RGB_img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized_RGB_img)
plt.show()

#3.
h, w, c = resized_RGB_img.shape
print("высота h", h)

#3_3
path = ''
file_name = 'result.jpg'

cv2.imwrite(path + file_name, resized_RGB_img)

import os

print("размер файла в байтах", os.path.getsize(path + file_name))
# Out:
# 1.7777777777777777
# высота h 500
# размер файла в байтах 102634
